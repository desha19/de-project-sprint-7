# %%
import sys
import os
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext, SparkSession, DataFrame
import pyspark.sql.functions as F
from pyspark.sql.window import Window 
from pyspark.sql.types import DateType

os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3"
os.environ["YARN_CONF_DIR"] = "/etc/hadoop/conf"
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
os.environ["HADOOP_CONF_DIR"] = "/etc/hadoop/conf/"

# %%
spark = SparkSession.builder \
                    .master("yarn") \
                    .appName("Project_7_2") \
                    .getOrCreate()
# Out:
# 24/09/03 10:50:03 WARN Utils: Your hostname, fhmugce59tbv43vsp0ua resolves to a loopback address: 127.0.1.1; using 172.16.0.3 instead (on interface eth0)
# 24/09/03 10:50:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/03 10:50:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/09/03 10:50:05 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/09/03 10:50:06 WARN Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.

# %%
# функция для чтения файла "/user/denis19/data/geo/cities/actual/geo.csv" и переобразования
def geo_transform(geo_path: str, sql) -> DataFrame:
    geo_transform_df = (sql.read.option("header", True)
            .option("delimiter", ";")
            .csv(geo_path)
            .withColumn("lat_g", F.regexp_replace("lat", ",", ".").cast('float'))
            .withColumn("lng_g", F.regexp_replace("lng", ",", ".").cast('float'))
            .drop("lat", "lng")
            .persist()
            )
    return geo_transform_df

# %%
# Test
geo_transform_df = geo_transform("/user/denis19/data/geo/cities/actual/geo.csv", spark)
geo_transform_df.show()
# Out:
# +---+----------+--------+--------+
# | id|      city|   lat_g|   lng_g|
# +---+----------+--------+--------+
# |  1|    Sydney| -33.865|151.2094|
# |  2| Melbourne|-37.8136|144.9631|
# |  3|  Brisbane|-27.4678|153.0281|
# |  4|     Perth|-31.9522|115.8589|
# |  5|  Adelaide|-34.9289|138.6011|
# |  6|Gold Coast|-28.0167|   153.4|
# |  7|Cranbourne|-38.0996|145.2834|
# |  8|  Canberra|-35.2931|149.1269|
# |  9| Newcastle|-32.9167|  151.75|
# | 10|Wollongong|-34.4331|150.8831|
# | 11|   Geelong|  -38.15|  144.35|
# | 12|    Hobart|-42.8806| 147.325|
# | 13|Townsville|-19.2564|146.8183|
# | 14|   Ipswich|-27.6167|152.7667|
# | 15|    Cairns|-16.9303|145.7703|
# | 16| Toowoomba|-27.5667|  151.95|
# | 17|    Darwin|-12.4381|130.8411|
# | 18|  Ballarat|  -37.55|  143.85|
# | 19|   Bendigo|  -36.75|144.2667|
# | 20|Launceston|-41.4419| 147.145|
# +---+----------+--------+--------+
# only showing top 20 rows

# %%
# функция чтения "/user/master/data/geo/events" с переименованием стобцов lat на lat_e и lon на lon_e
def events_transform(events_path: str, sql) -> DataFrame:
    events_transform_df = (sql
                  .read.parquet(f'{events_path}')
                  .where('event_type = "message"')
                  .select("event.message_id", "event.message_from","event_type", "lat", "lon", "date")
                  .where('lat IS NOT NULL and lon IS NOT NULL')
                  .withColumnRenamed("lat", "lat_e")  # переименование lat на lat_e
                  .withColumnRenamed("lon", "lon_e")  # переименование lon на lon_e
                  .persist()
                  )
    return events_transform_df

# %%
# Test
events_transform_df = events_transform("/user/master/data/geo/events", spark)
events_transform_df.show()
# Out:
# 24/09/03 10:50:59 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# [Stage 6:>                                                          (0 + 1) / 1]
# +----------+------------+----------+-------------------+------------------+----------+
# |message_id|message_from|event_type|              lat_e|             lon_e|      date|
# +----------+------------+----------+-------------------+------------------+----------+
# |   1124422|       69134|   message|-16.046503973624315|145.82512282136813|2022-05-30|
# |   1092067|      131912|   message|-36.858935432847716|145.43211674632613|2022-05-29|
# |    643541|      117616|   message| -34.81927333434335| 138.8583508497529|2022-05-27|
# |   1109058|      133551|   message| -34.70560960193741|149.36954006694884|2022-05-25|
# |   1115074|       54215|   message| -16.71130585448509|146.15829631028848|2022-05-22|
# |   1131184|      103235|   message| -33.94742527623598|151.32387878072961|2022-05-21|
# |   1131046|      107808|   message|-11.539551427762717|131.17148068495302|2022-05-21|
# |    311869|       85381|   message|-20.394696238744967|150.08215379975078|2022-05-20|
# |    817590|       87739|   message|-27.626513021017026|154.02481889583558|2022-05-18|
# |   1123080|       30811|   message| -35.16449792511492|149.32723629674092|2022-05-16|
# |    947949|       85381|   message|-33.724146553225445|151.49085475607845|2022-05-16|
# |    740244|      108723|   message|-37.242519731639554|145.96126970968916|2022-05-16|
# |    987225|       85381|   message| -42.67367177351411|148.29285749816125|2022-05-15|
# |    959056|      115998|   message| -34.06918975185467|151.74202754967064|2022-05-15|
# |    279341|        3569|   message| -27.52411419486454|152.29277203560846|2022-05-14|
# |    574275|       45104|   message| -32.23913242798448|152.15435196041906|2022-05-14|
# |    727554|       87824|   message|-16.718215197042035| 146.1136983041421|2022-05-14|
# |    639434|      117616|   message|-11.531719581633588|131.24166414819894|2022-05-14|
# |    763243|      134160|   message| -32.40594211402352|152.32437491395635|2022-05-14|
# |   1106057|      100875|   message| -42.25029184492201|148.01306738725233|2022-05-13|
# +----------+------------+----------+-------------------+------------------+----------+
# only showing top 20 rows

# %%
def events_with_geo(events_transform_df: DataFrame, geo_transform_df: DataFrame) -> DataFrame:
    events_with_geo_df = (
        events_transform_df
        # при помощи кросс джоин происходит объединение двух датафреймов "events_df" и "geo_df"
        .crossJoin(geo_transform_df)
        # вычисление расстояния между координатами событий и географическими координатами и именуеься столбцом "distance"
        .withColumn("distance", F.lit(2) * F.lit(6371) * F.asin(
        F.sqrt(
            F.pow(F.sin((F.col("lat_e") - F.col("lat_g"))/F.lit(2)),2)
            + F.cos(F.col("lat_g"))*F.cos(F.col("lat_e"))*
            F.pow(F.sin((F.col("lon_e") - F.col("lng_g"))/F.lit(2)),2)
        )))
        .drop("lat_e","lon_e", "lat_g", "lng_g"))
    # при помощи оконной функции происходит выбор ближайщего географического объекта для каждого события, основываясь на минемальном расстоянии
    window = Window().partitionBy("message_id").orderBy(F.col("distance").asc())
    events_with_geo_df = (
        events_with_geo_df
        .withColumn("row_number", F.row_number().over(window))
        .filter(F.col("row_number")==1)
        .drop("row_number", "distance")
        # добавляется уникальный идентификатор "event_id" для каждого события
        .withColumn("event_id", F.monotonically_increasing_id())
        # выбор и переименование столбцов для удобства дальнейшей обработки
        .selectExpr("message_id", "message_from as user_id", "event_id", "event_type", "id as zone_id", "city", "date")
        .persist()
    )
    
    return events_with_geo_df

# %%
# Test
events_with_geo_df = events_with_geo(events_transform_df, geo_transform_df)
events_with_geo_df.show()
# Out:
# [Stage 11:=====================================================>(197 + 2) / 200]
# +----------+-------+--------+----------+-------+-----------+----------+
# |message_id|user_id|event_id|event_type|zone_id|       city|      date|
# +----------+-------+--------+----------+-------+-----------+----------+
# |        26|  59169|       0|   message|     21|     Mackay|2022-01-20|
# |       964|   1381|       1|   message|     19|    Bendigo|2022-04-11|
# |      1950|  98393|       2|   message|      8|   Canberra|2022-01-24|
# |      2453|  29427|       3|   message|      9|  Newcastle|2022-02-26|
# |      2529|  19029|       4|   message|      3|   Brisbane|2022-02-21|
# |      3091| 143033|       5|   message|      8|   Canberra|2022-01-07|
# |      3506|  27162|       6|   message|     20| Launceston|2022-04-05|
# |      3764|  26202|       7|   message|     19|    Bendigo|2022-01-04|
# |      4590| 162869|       8|   message|     22|Rockhampton|2022-04-18|
# |      4823|  43453|       9|   message|     19|    Bendigo|2022-01-31|
# |      5385| 152640|      10|   message|      9|  Newcastle|2022-02-06|
# |      5409|  34231|      11|   message|      5|   Adelaide|2022-02-10|
# |      5556|  47259|      12|   message|      7| Cranbourne|2022-05-01|
# |      6721|  46233|      13|   message|     20| Launceston|2022-05-01|
# |      7225| 121703|      14|   message|     24|    Bunbury|2022-03-20|
# |      8075|  36000|      15|   message|      1|     Sydney|2022-02-10|
# |      8440|  41171|      16|   message|      8|   Canberra|2022-04-10|
# |      9945|  72271|      17|   message|      5|   Adelaide|2022-02-28|
# |      9968| 100549|      18|   message|     19|    Bendigo|2022-01-16|
# |      9978|  29267|      19|   message|      1|     Sydney|2022-01-06|
# +----------+-------+--------+----------+-------+-----------+----------+
# only showing top 20 rows

# %%
# Зоздать новую функцию
#def travel_calc(events_with_geo_df: DataFrame):
 # группировка данных по "user_id", считая количество путешествий "travel_count" и список городов "travel_array", которые посетил пользователь
    #travel_calc_df = (
        #events_with_geo_df
        #.groupBy("user_id")
        #.agg(
            #F.count("*").alias("travel_count"),
            #F.collect_list("city").alias("travel_array")
        #)
        # объединение агрегированных данных с исходным датафрейм
        #.join(events_with_geo_df, "user_id")
        #.selectExpr("user_id", "travel_count", "travel_array")
        #.persist()
    #)
    
    #return travel_calc_df 
    
def travel_calc(events_with_geo_df: DataFrame) -> DataFrame:
    # Группировка данных по "user_id", считая количество путешествий "travel_count" и список городов "travel_array", которые посетил пользователь
    travel_calc_df = (
        events_with_geo_df
        .groupBy("user_id")
        .agg(
            F.count("*").alias("travel_count"),
            F.collect_list("city").alias("travel_array")
        )
    )
    
    return travel_calc_df

# %%
# Test
travel_calc_df = travel_calc(events_with_geo_df)
travel_calc_df.show()
# Out:
# [Stage 15:=====================================================>(199 + 1) / 200]
# +-------+------------+--------------------+
# |user_id|travel_count|        travel_array|
# +-------+------------+--------------------+
# |      1|           2|[Bunbury, Rockham...|
# |      5|           6|[Hobart, Hobart, ...|
# |      7|           2|[Melbourne, Melbo...|
# |      9|           4|[Hobart, Cairns, ...|
# |     17|           1|          [Canberra]|
# |     25|           6|[Maitland, Maitla...|
# |     26|           2|[Wollongong, Woll...|
# |     27|           5|[Cranbourne, Woll...|
# |     28|           1|            [Sydney]|
# |     29|           1|        [Wollongong]|
# |     31|           3|[Bunbury, Bunbury...|
# |     32|           1|           [Geelong]|
# |     34|           6|[Newcastle, Newca...|
# |     43|           3|[Cranbourne, Cran...|
# |     44|           2|   [Bendigo, Mackay]|
# |     48|          95|[Maitland, Perth,...|
# |     50|           1|            [Darwin]|
# |     51|           1|           [Bendigo]|
# |     52|           4|[Newcastle, Newca...|
# |     54|           4|[Bendigo, Bendigo...|
# +-------+------------+--------------------+
# only showing top 20 rows

# %%
def actual_geo(events_with_geo_df: DataFrame) -> DataFrame:
    # при помощи оконной функции происходит группировка строй по "user_id" и упорядочивает их по "data" в порядке убывания
    window = Window().partitionBy("user_id").orderBy(F.col("date").desc())
    actual_geo_df = (events_with_geo_df
            # добавление нового столбца "row_number", который присваивает каждой строке номер в пределах окна
            .withColumn("row_number", F.row_number().over(window))
            # оставляем строки "row_number" только с номером 1, то есть последние события для каждого пользователя
            .filter(F.col("row_number") == 1)
            .selectExpr("message_id", "user_id", "city", "zone_id") # убрал "travel_count", "travel_array"
            .persist()
           )
    return actual_geo_df

# %%
# Test
actual_geo_df = actual_geo(events_with_geo_df)
actual_geo_df.show()
# Out:
# +----------+-------+-----------+-------+
# |message_id|user_id|       city|zone_id|
# +----------+-------+-----------+-------+
# |    693079|     26| Wollongong|     10|
# |    727911|     29| Wollongong|     10|
# |      4260|    474|  Toowoomba|     16|
# |   1108716|    964|     Hobart|     12|
# |   1133013|   1677|Rockhampton|     22|
# |    806829|   1697|  Toowoomba|     16|
# |    999257|   1806|     Mackay|     21|
# |    718259|   2040|  Toowoomba|     16|
# |    641269|   2214|   Canberra|      8|
# |   1023768|   2250|    Geelong|     11|
# |    128885|   2453|   Adelaide|      5|
# |     51154|   2509| Cranbourne|      7|
# |    324844|   2529|     Mackay|     21|
# |    755145|   2927| Cranbourne|      7|
# |    714293|   3506|     Sydney|      1|
# |   1127802|   3764|     Hobart|     12|
# |    384146|   5385|  Melbourne|      2|
# |    667362|   5409|     Sydney|      1|
# |   1119470|   6721|    Bendigo|     19|
# |   1090923|   7279| Townsville|     13|
# +----------+-------+-----------+-------+
# only showing top 20 rows
# 24/09/03 11:51:45 WARN CacheManager: Asked to cache already cached data.

# %%
def travel_geo(events_with_geo_df: DataFrame) -> DataFrame:
    # при омощи оконной функции группируеи строки "user_id" и "message_id", упорядочивая их по "data"
    window = Window().partitionBy("user_id", "message_id").orderBy(F.col("date"))
    travel_geo_df = (
        events_with_geo_df
        # добавляем новый столбец "dense_rank", который присваивает каждой строке ранг в пределах окна
        .withColumn("dense_rank", F.dense_rank().over(window))
        # добавляем новый столбец "date_diff", который вычисляет разницу в днях между датой события и преобразованным значением "dense_rank"
        .withColumn("date_diff", F.datediff(
            F.col('date').cast(DateType()), F.to_date(F.col("dense_rank").cast("string"), "d")
            )
        )
        .selectExpr("date_diff", "user_id as user", "date", "message_id", "zone_id")
        # группируем строки по "user", "date_diff", "zone_id", посчитывая количество событий "cnt_city" для каждой группы
        .groupBy("user", "date_diff", "zone_id")
        .agg(F.count(F.col("date")).alias("cnt_city"))
        .persist()
        )
    return travel_geo_df

# %%
# Test
travel_geo_df = travel_geo(events_with_geo_df)
travel_geo_df.orderBy(F.col("cnt_city").desc()).show()
# Out:
# 24/09/03 11:52:07 WARN CacheManager: Asked to cache already cached data.
# [Stage 82:=================================================>    (185 + 1) / 200]
# +-----+---------+-------+--------+
# | user|date_diff|zone_id|cnt_city|
# +-----+---------+-------+--------+
# |62449|    19002|      8|     550|
# |36000|    19032|      5|     464|
# |62449|    19003|      8|     437|
# |62449|    19004|      8|     425|
# |14764|    19088|      8|     418|
# |82914|    19008|      9|     376|
# |36000|    19033|      5|     365|
# |62449|    19005|      8|     363|
# |14764|    19089|      8|     335|
# |82914|    19009|      9|     323|
# |36000|    19034|      5|     322|
# |82914|    19007|      9|     312|
# |14764|    19090|      8|     301|
# |36000|    19035|      5|     284|
# |62449|    19007|      8|     278|
# |62449|    19006|      8|     262|
# |82914|    19010|      9|     249|
# |14764|    19091|      8|     248|
# |36000|    19036|      5|     246|
# |23807|    19056|     21|     240|
# +-----+---------+-------+--------+
# only showing top 20 rows

# %%
def home_geo(travel_geo_df: DataFrame) -> DataFrame:
    home_city_df = (
        travel_geo_df
        # оставляем строки, где "cnt_city" больше 27
        .filter((F.col("cnt_city") > 27))
        # добавляем новый столбец "max_dt", который содержит максимальное значение "date_diff" для каждого пользователя   
        .withColumn("max_dt", F.max(F.col("date_diff")).over(Window().partitionBy("user"))) 
        # оставляем только те строки, где "data_diff" равен "max_dt"
        .filter(F.col("date_diff") == F.col("max_dt"))       
        .persist()
    )
    return home_city_df

# %%
# Test
home_geo_df = home_geo(travel_geo_df)
home_geo_df.show()
# Out:
# 24/09/03 11:52:25 WARN CacheManager: Asked to cache already cached data.
# +------+---------+-------+--------+------+
# |  user|date_diff|zone_id|cnt_city|max_dt|
# +------+---------+-------+--------+------+
# | 40989|    19005|     24|      48| 19005|
# | 60039|    19079|      5|      37| 19079|
# |117522|    19113|     23|      36| 19113|
# | 74378|    19056|      1|      34| 19056|
# | 12029|    19017|     21|      30| 19017|
# | 21174|    19101|     19|      41| 19101|
# |125598|    19079|      5|      29| 19079|
# |   624|    19102|      7|      40| 19102|
# | 83308|    19032|     22|      32| 19032|
# | 21395|    19114|      9|      35| 19114|
# | 33168|    19039|     21|      30| 19039|
# |  4278|    19074|     21|      31| 19074|
# | 84783|    19032|     10|      31| 19032|
# |126334|    19120|     19|      32| 19120|
# | 46233|    19116|     20|      31| 19116|
# |110188|    19000|     21|      30| 19000|
# | 57678|    18995|     22|      36| 18995|
# | 52110|    19083|      2|      39| 19083|
# | 15380|    19011|     19|      35| 19011|
# | 62333|    19012|      8|      28| 19012|
# +------+---------+-------+--------+------+
# only showing top 20 rows

# %%
def merge_actual_and_home_geo(actual_geo_df: DataFrame, home_geo_df: DataFrame, geo_transform_df: DataFrame) -> DataFrame:
    geo_transform_df = geo_transform_df.select("id", "city")
    home_geo_df = (
        # объединяем "home_geo_df" с "geo_transform_df" по "zone_id" и "id", что бы получить название домашнего города "home_city". Затем выбираем столбцы "user" и "home_city"
        home_geo_df
        .join(geo_transform_df, home_geo_df.zone_id == geo_transform_df.id, "inner")
        .selectExpr("user", "city as home_city")
    )

    merge_actual_and_home_geo_df = (
    # объединяем "actual_geo_df" c "home_geo_df" по "user_id" и "user" соотвественно с использованем полного внешнего соединения. Затем выбираем нужные столбцы и переименовываем
       actual_geo_df
       .join(home_geo_df, actual_geo_df.user_id == home_geo_df.user, "fullouter")
       .selectExpr("user_id", "city as act_city", "home_city")  # Убрал поля "travel_count", "travel_array"
       .persist()
    )
    return merge_actual_and_home_geo_df

# %%
# Test
merge_actual_and_home_geo_df = merge_actual_and_home_geo(actual_geo_df, home_geo_df, geo_transform_df)
merge_actual_and_home_geo_df.filter(F.col("home_city").isNotNull()).show()
# Out:
# 24/09/03 11:57:35 WARN CacheManager: Asked to cache already cached data.
# +-------+-----------+-----------+
# |user_id|   act_city|  home_city|
# +-------+-----------+-----------+
# |  40989|  Newcastle|    Bunbury|
# |  60039|   Adelaide|   Adelaide|
# | 117522|   Maitland|   Maitland|
# |  74378|     Sydney|     Sydney|
# |  12029|  Newcastle|     Mackay|
# |  21174|    Bendigo|    Bendigo|
# | 125598|   Adelaide|   Adelaide|
# |    624| Cranbourne| Cranbourne|
# |  83308|Rockhampton|Rockhampton|
# |  21395| Wollongong|  Newcastle|
# |  33168|    Geelong|     Mackay|
# |   4278|     Mackay|     Mackay|
# |  84783|    Geelong| Wollongong|
# | 126334|    Bendigo|    Bendigo|
# |  46233| Launceston| Launceston|
# | 110188|     Mackay|     Mackay|
# |  57678|  Newcastle|Rockhampton|
# |  52110|  Melbourne|  Melbourne|
# |  15380|    Bendigo|    Bendigo|
# |  62333|   Canberra|   Canberra|
# +-------+-----------+-----------+
# only showing top 20 rows

# %%
def mart_users_cities(events_path: DataFrame, merge_actual_and_home_geo_df: DataFrame, travel_calc: DataFrame, sql) -> DataFrame:
    times = (
        # загружаем данные из паркет файла, фильтруем собятия типа "message" и выбираем нужные поля
        sql.read.parquet(f'{events_path}')
        .where('event_type = "message"')
        .selectExpr("event.message_from as user_id", "event.datetime", "event.message_id")
        .where("datetime IS NOT NULL")
    )
    # при помощи оконной функции группируем строки по "user_id" и упорядочиваем их по "datetime" в порядке убывания
    window = Window().partitionBy('user_id').orderBy(F.col('datetime').desc())

    times_w = (times
            # добавляем столбец "row_number", который присваивает каждой строки номер в пределах окна
            .withColumn("row_number", F.row_number().over(window))
            # оставляем только те строки с "row_number" равным 1 (последнее событие для каждого пользователя)
            .filter(F.col("row_number")==1)
            # преобразуем поле "datetime" в тип "Timestamp" и отбираем столбцы "user" и "Time"
            .withColumn("TIME", F.col("datetime").cast("Timestamp"))
            .selectExpr("user_id as user", "Time")
    )

    mart_users_cities_df = (
        # объединяем "merge_actual_and_home_geo_df" с "times_w" по "user_id" и "user" соотвественно
        merge_actual_and_home_geo_df
        .join(times_w, merge_actual_and_home_geo_df.user_id == times_w.user, "left").drop("user")
        # добавляем часовой пояс "timezone" при помощи объединения "Australia/" с названием фактического города "act_city"
        .withColumn("timezone",F.concat(F.lit("Australia/"),F.col("act_city")))
        # столбец с текущей меткой времени
        .withColumn("processed_dttm", F.current_timestamp())
        # добавляем столбец "local_time", который вычисляет локальное время. 
	    # Так как функция "from_utc_timestamp" содержит ограниченный список городов, вычисления местного времени будут проводиться не для всех городов.
        .withColumn("local_time", 
                    F.when( F.col("act_city")
                    .isin("Sydney", "Melbourne", "Brisbane", "Perth", "Adelaide", "Canberra", "Hobart", "Darwin"), 
                    F.from_utc_timestamp(
                    F.col("processed_dttm"), 
                    F.concat(F.lit("Australia/"), 
                    F.col("act_city"))))
                    .otherwise(None))
        .join(travel_calc, merge_actual_and_home_geo_df.user_id == travel_calc.user_id, "left")  # добавил соединение "travel_calc"
        .select(merge_actual_and_home_geo_df["user_id"], "act_city", "home_city", "travel_count", "travel_array", "local_time")
        .persist()
        )
    
    return mart_users_cities_df

# %%
# Test
mart_users_cities_df = mart_users_cities("/user/master/data/geo/events", merge_actual_and_home_geo_df, travel_calc_df, spark)
mart_users_cities_df.orderBy(F.col("home_city").desc()).show()
# Out:
# [Stage 157:===========================================>         (164 + 1) / 200]0]
# +-------+-----------+-----------+------------+--------------------+--------------------+
# |user_id|   act_city|  home_city|travel_count|        travel_array|          local_time|
# +-------+-----------+-----------+------------+--------------------+--------------------+
# |  84783|    Geelong| Wollongong|         321|[Melbourne, Wollo...|                NULL|
# |  33581| Wollongong| Wollongong|         273|[Wollongong, Woll...|                NULL|
# | 152054|    Bendigo| Wollongong|         339|[Wollongong, Woll...|                NULL|
# | 119895|Rockhampton| Wollongong|         432|[Wollongong, Woll...|                NULL|
# | 136526| Wollongong| Wollongong|         249|[Adelaide, Wollon...|                NULL|
# |   8523| Wollongong| Wollongong|         255|[Newcastle, Wollo...|                NULL|
# |  10279| Townsville| Townsville|         806|[Townsville, Town...|                NULL|
# | 131760|   Canberra| Townsville|         283|[Townsville, Town...|2024-09-03 22:11:...|
# |  62337|  Newcastle|  Toowoomba|         596|[Toowoomba, Maitl...|                NULL|
# |  80680|     Darwin|  Toowoomba|         411|[Toowoomba, Toowo...|2024-09-03 21:41:...|
# |  65115|  Toowoomba|  Toowoomba|         828|[Toowoomba, Toowo...|                NULL|
# |   9428|     Sydney|     Sydney|         335|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |  90346|     Sydney|     Sydney|         484|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |   6817|     Sydney|     Sydney|         285|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |  20746|     Sydney|     Sydney|         321|[Geelong, Sydney,...|2024-09-03 22:11:...|
# | 160715|     Sydney|     Sydney|         491|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |  59456|     Sydney|     Sydney|         857|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |  74378|     Sydney|     Sydney|         390|[Sydney, Sydney, ...|2024-09-03 22:11:...|
# |  20393|Rockhampton|Rockhampton|         265|[Rockhampton, Roc...|                NULL|
# |   5192|Rockhampton|Rockhampton|         462|[Rockhampton, Roc...|                NULL|
# +-------+-----------+-----------+------------+--------------------+--------------------+
# only showing top 20 rows
# 24/09/03 13:18:05 WARN HeartbeatReceiver: Removing executor 2 with no recent heartbeats: 129430 ms exceeds timeout 120000 ms
# 24/09/03 13:18:05 ERROR YarnScheduler: Lost executor 2 on rc1a-dataproc-d-5w4oxa2s5b8foehs.mdb.yandexcloud.net: Executor heartbeat timed out after 129430 ms
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_341 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_169 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_100 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_36 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_32 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_566 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1158 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_180 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_464 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_118 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1179 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1370 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_76 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_12 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_586 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_909 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1183 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1173 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_196 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1094 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1131 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_24 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_197 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1247 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1416 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_146 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_123 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_141 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_162 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_650 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_27 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_89 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_18 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_4 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_101 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_36 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1160 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1013 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_137 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_530 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_66 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_97 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_158 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_49 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1287 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_192 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_901 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1325 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_438 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_529 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_752 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1132 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_185 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_810 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_600 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_146 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_692 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_131 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_356 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_402 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_439 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_104 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_776 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_938 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_845 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1341 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_397 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1091 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_778 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_842 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_63 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_657 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_137 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_7 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1039 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1239 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_9 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_729 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_185 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_143 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1171 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1017 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_66 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1372 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_780 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_151 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_109 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1155 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_375 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_120 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1278 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_953 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1097 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1402 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_939 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1260 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_25 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1375 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_180 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_225 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_214 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_279 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_69 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_761 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_783 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1447 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_198 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1303 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_26 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_76 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_35 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_684 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_55 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_188 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_250 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_12 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_90 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_462 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_4 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1125 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_153 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_63 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_61 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_141 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_51 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_84 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_660 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1100 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_47 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_273 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_945 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_972 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_115 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_979 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_96 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_82 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_158 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1436 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_79 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_139 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_814 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_424 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_161 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_72 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_975 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1193 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1187 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1379 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1440 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_50 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_790 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_475 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1235 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_213 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1128 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_957 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_148 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_132 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1241 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_60 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_696 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_173 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_50 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_546 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_82 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1232 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_344 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1116 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_897 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_300 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_847 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_0 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1283 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_16 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_283 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_26 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_19 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_38 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_48 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_208 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_134 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_345 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_792 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1020 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_68 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_107 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1307 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_573 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_10 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1312 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_29 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_187 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_26 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_177 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1395 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_187 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_115 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1119 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_64 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1282 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_636 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1292 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_667 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1301 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_197 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_14 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_99 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_866 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_195 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1170 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_94 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_190 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_442 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1320 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1162 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_139 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_156 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1430 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_53 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1083 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_134 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_182 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_669 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_97 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_683 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_668 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1360 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_190 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_911 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_137 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_148 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_689 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_18 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1048 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1051 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_688 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_201 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_608 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_561 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_187 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_184 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_153 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_64 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_334 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_590 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1129 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_633 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_5 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_423 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_110 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_816 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_88 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_137 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1251 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_195 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_18 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_57 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_56 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_426 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_17 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_34 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_16 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_14 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1077 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_50 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_769 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_63 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_330 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1196 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_45 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_57 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_23 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_189 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_99 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_863 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_31 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_800 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_173 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_132 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_678 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_192 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_190 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_99 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_164 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_999 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_4 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1117 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_144 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_189 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_144 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1358 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_33 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_144 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1081 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_867 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_92 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_984 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1433 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_94 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1334 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_140 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_676 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_53 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_39 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_709 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_282 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_86 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1454 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_22 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_76 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_38 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1204 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_145 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1060 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_124 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1029 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1220 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_29 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_179 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1281 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_115 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_100 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_145 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1049 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1121 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1101 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_115 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_142 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_63 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_151 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1268 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1463 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_576 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1408 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_976 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_174 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_68 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_82 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_36 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_23 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_123 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_470 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_841 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1439 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_184 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_484 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1047 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_82 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1385 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_69 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1209 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_719 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1167 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_619 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_7 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_157 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_57 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_135 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_174 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_123 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_23 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_848 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_127 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_645 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_519 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1397 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_189 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_66 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_431 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_620 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_894 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1093 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_150 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_84 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_105 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_90 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1361 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_142 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1079 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_88 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_29 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_87 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_42 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_158 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_947 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_297 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1351 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_124 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_76 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_876 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_21 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_75 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1410 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_472 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_16 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_507 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_120 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_142 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_50 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1294 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_148 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_137 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_113 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_10 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1345 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1076 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_4 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1064 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1202 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_147 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_762 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1102 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_369 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1107 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_142 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_79 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_84 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_293 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1211 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_277 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_339 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1072 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_174 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_73 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_107 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_904 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_441 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_469 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1096 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_870 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_666 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_212 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_13 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_118 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_94 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1045 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_97 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_862 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_107 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_878 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_187 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_983 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1267 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_157 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_204 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1418 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_16 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_965 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_537 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_127 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_43 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_528 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_885 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_138 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_730 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_120 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1055 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_771 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_120 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1355 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_54 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_106 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_98 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_130 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_171 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_110 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_102 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_163 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_165 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_23 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1466 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1423 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_691 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1191 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_795 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_92 !
# ...
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1175 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1296 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_175 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_690 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_40 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1034 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1401 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_166 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_661 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1369 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_43 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_377 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_952 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_516 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1386 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_488 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_383 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_177 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_97 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_366 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_133 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_350 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_153 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_85 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_481 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_829 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1059 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_152 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_8 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_161 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_103 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1114 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_167 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1437 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_379 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1311 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_67 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_86 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_71 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_459 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_169 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_160 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_849 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1022 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1124 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_179 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1273 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_6 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_649 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_706 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1156 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_92 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_153 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_164 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1330 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_993 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_150 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_47 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_119 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1350 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_883 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1425 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1245 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1274 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_66 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_968 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_191 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1221 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_127 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_45 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1328 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_100 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_192 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_701 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_388 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_832 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_195 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_33 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_53 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_94 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_16 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1218 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_135 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_119 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1347 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_0 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_102 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_357 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_264 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_84 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1444 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_89 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_57 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_164 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_362 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_732 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_100 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_199 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_139 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_182 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_266 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1459 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_26 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_34 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1148 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_353 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_104 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_843 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1227 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_0 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1106 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1089 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_553 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_126 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_714 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_96 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_110 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1028 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1198 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_120 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1082 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_103 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_71 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_970 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1231 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_50_51 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_47 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_411 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_308 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_245 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1429 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_258 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_71 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_110 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_127 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1452 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_32 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_68 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_79 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1462 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_21 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_289 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1056 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_923 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_734 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_10 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_107 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_597 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_105 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_87 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_224_184 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_82 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_122 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_682 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_35 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_21 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_161 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_126_171 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1387 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_38 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_117 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_147_151 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_809 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_108_169 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_206 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_28_1222 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_76_38 !
# 24/09/03 13:18:05 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_92_87 !

# %%
def main() -> None:
    events_path = sys.argv[1]
    geo_path = sys.argv[2]
    output_path = sys.argv[3]
    #events_path = "/user/master/data/geo/events/"
    #geo_path = "/user/denis19/data/geo/cities/actual/geo.csv"
    #output_path = "/user/denis19/analytics/showcase_by_users"

    conf = (SparkConf()
        .setAppName("showcase_recommendations_to_friends")
        .set("spark.executor.memory", "4g")
        .set("spark.driver.memory", "4g"))
    sc = SparkContext(conf=conf)
    sql = SQLContext(sc)

    geo_transform_df = geo_transform(geo_path, sql)
    events_transform_df = events_transform(events_path, sql)
    events_with_geo_df = events_with_geo(events_transform_df, geo_transform_df)
    actual_geo_df = actual_geo(events_with_geo_df)
    travel_geo_df = travel_geo(events_with_geo_df)
    home_geo_df = home_geo(travel_geo_df)
    merge_actual_and_home_geo_df = merge_actual_and_home_geo(actual_geo_df, home_geo_df, geo_transform_df)
    mart_users_cities_df = mart_users_cities(events_path, merge_actual_and_home_geo_df, sql)
    write = mart_users_cities_df.write.mode("overwrite").parquet(f'{output_path}')

    return write

# %%
if __name__ == "__main__":
        main()
